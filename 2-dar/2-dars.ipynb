# %%
import pandas as pd

# %%
df=pd.read_csv('Netflix TV Shows and Movies.csv')

# %%
# data haqida umumiy malumot
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   object
#  1   id                 5281 non-null   object
#  2   title              5283 non-null   object
#  3   type               5282 non-null   object
#  4   description        5278 non-null   object
#  5   release_year       5283 non-null   object
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   object
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5266 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 454.1+ KB

# %%
# data  boshidan 5 taqator yoki ustunlar nomini ko'rishda
df.head()
# Out:
#   index        id                            title   type  \
# 0     0   tm84618                      Taxi Driver  MOVIE
# 1     1   tm17384  Monty Python and the Holy Grail  MOVIE
# 2     2      0993                    Life of Brian  MOVIE
# 3     3  tm190788                     The Exorcist  MOVIE
# 4     4   ts22164     Monty Python's Flying Circus   SHOW
#
#                                          description release_year  \
# 0  A mentally unstable Vietnam War veteran works ...         1976
# 1  King Arthur, accompanied by his squire, recrui...         1975
# 2  Brian Cohen is an average young Jewish man, bu...         1979
# 3  12-year-old Regan MacNeil begins to adapt an e...         1973
# 4  A British sketch comedy series with the shows ...         1969
#
#   age_certification runtime    imdb_id  imdb_score  imdb_votes
# 0                 R     113  tt0075314         8.3    795222.0
# 1                PG      91  tt0071853         8.2    530877.0
# ...

# %%
#  dataning oxiridan 5ta qator va undan ko'proq
df.tail()
# Out:
#      index         id                               title   type  \
# 5278  5278  tm1040816         Momshies! Your Soul is Mine  MOVIE
# 5279  5279  tm1014599                           Fine Wine  MOVIE
# 5280  5280  tm1045018                               Clash  MOVIE
# 5281  5281  tm1098060                      Shadow Parties  MOVIE
# 5282  5282   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description release_year  \
# 5278  Three women with totally different lives accid...         2021
# 5279  A beautiful love story that can happen between...         2021
# 5280  A man from Nigeria returns to his family in Ca...         2021
# 5281  A family faces destruction in a long-running c...         2021
# 5282  With winter behind them, Bheem and his townspe...         2021
#
#      age_certification runtime     imdb_id  imdb_score  imdb_votes
# 5278               NaN     108  tt14412240         5.8        26.0
# ...

# %%
# berilgan datadagi tushub qolganlr us tunlar 
df.isnull().sum()
# Out:
# index                   0
# id                      2
# title                   0
# type                    1
# description             5
# release_year            0
# age_certification    2285
# runtime                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes             17
# dtype: int64

# %%
df.head(20)
# Out:
#        index               id                                      title  \
# 0          0          tm84618                                Taxi Driver
# 1          1          tm17384            Monty Python and the Holy Grail
# 2          2             0993                              Life of Brian
# 3          3         tm190788                               The Exorcist
# 4          4          ts22164               Monty Python's Flying Circus
# 5          5          tm14873                                Dirty Harry
# 6          6              NaN                               My Fair Lady
# 7   7tm98978  The Blue Lagoon                                      MOVIE
# 8          8         tm119281                           Bonnie and Clyde
# 9          9          tm67378                          The Professionals
# 10        10          tm44204                       The Guns of Navarone
# 11        11          tm69778  Lupin the Third: The Castle of Cagliostro
# ...

# %%
# berilgan datada NON qiymat bo'lgan ustunlarni nomini ko'rsatuvchi cod
df.columns[df.isnull().any()]
# Out:
# Index(['id', 'type', 'description', 'age_certification', 'imdb_votes'], dtype='object')

# %%
df[df.isnull().any(axis=1)] 
#   NON qiymatlar mavjud qator  nomlarini ko'rsatish
# Out:
#          index               id                               title  \
# 6            6              NaN                        My Fair Lady
# 7     7tm98978  The Blue Lagoon                               MOVIE
# 10          10          tm44204                The Guns of Navarone
# 14          14          tm16479                     White Christmas
# 15          15         tm135083                       Cairo Station
# ...        ...              ...                                 ...
# 5278      5278        tm1040816         Momshies! Your Soul is Mine
# 5279      5279        tm1014599                           Fine Wine
# 5280      5280        tm1045018                               Clash
# 5281      5281        tm1098060                      Shadow Parties
# 5282      5282         ts271048  Mighty Little Bheem: Kite Festival
#
#                                                    type  \
# 6                                                 MOVIE
# ...

# %%
#ATORLAR bo‘yicha tekshirmoqchi bo‘lsangiz	axis=1
#STUNLAR bo‘yicha tekshirmoqchi bo‘lsangiz	axis=0

# %%
df.mean(axis=0)	#ar bir ustun uchun o‘rtacha qiymatni hisoblaydi
df.mean(axis=1)	#ar bir qator uchun o‘rtacha qiymatni hisoblaydi

# %%
# berilgan datadagi malum bir ustunni ko'rish
df['type']
# Out:
# 0       MOVIE
# 1       MOVIE
# 2       MOVIE
# 3       MOVIE
# 4        SHOW
#         ...
# 5278    MOVIE
# 5279    MOVIE
# 5280    MOVIE
# 5281    MOVIE
# 5282     SHOW
# Name: type, Length: 5283, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5283 non-null   object
#  1   id                 5281 non-null   object
#  2   title              5283 non-null   object
#  3   type               5282 non-null   object
#  4   description        5278 non-null   object
#  5   release_year       5283 non-null   object
#  6   age_certification  2998 non-null   object
#  7   runtime            5283 non-null   object
#  8   imdb_id            5283 non-null   object
#  9   imdb_score         5283 non-null   float64
#  10  imdb_votes         5266 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 454.1+ KB

# %%
df['age_certification']
# Out:
# 0           R
# 1          PG
# 2           R
# 3           R
# 4       TV-14
#         ...
# 5278      NaN
# 5279      NaN
# 5280      NaN
# 5281      NaN
# 5282      NaN
# Name: age_certification, Length: 5283, dtype: object

# %%
df[['description','title']]
# Out:
#                                             description  \
# 0     A mentally unstable Vietnam War veteran works ...
# 1     King Arthur, accompanied by his squire, recrui...
# 2     Brian Cohen is an average young Jewish man, bu...
# 3     12-year-old Regan MacNeil begins to adapt an e...
# 4     A British sketch comedy series with the shows ...
# ...                                                 ...
# 5278  Three women with totally different lives accid...
# 5279  A beautiful love story that can happen between...
# 5280  A man from Nigeria returns to his family in Ca...
# 5281  A family faces destruction in a long-running c...
# 5282  With winter behind them, Bheem and his townspe...
#
#                                    title
# 0                            Taxi Driver
# 1        Monty Python and the Holy Grail
# 2                          Life of Brian
# 3                           The Exorcist
# 4           Monty Python's Flying Circus
# ...

# %%
df['age_certification','runtime'] #uyerda qo'shimcha ustun nomi kiritilsa ishlamayabdi sababi?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('age_certification', 'runtime')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#          index               id                               title  \
# 6            6              NaN                        My Fair Lady
# 7     7tm98978  The Blue Lagoon                               MOVIE
# 10          10          tm44204                The Guns of Navarone
# 14          14          tm16479                     White Christmas
# 15          15         tm135083                       Cairo Station
# ...        ...              ...                                 ...
# 5278      5278        tm1040816         Momshies! Your Soul is Mine
# 5279      5279        tm1014599                           Fine Wine
# 5280      5280        tm1045018                               Clash
# 5281      5281        tm1098060                      Shadow Parties
# 5282      5282         ts271048  Mighty Little Bheem: Kite Festival
#
#                                                    type  \
# 6                                                 MOVIE
# ...

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['id', 'type', 'description', 'age_certification', 'imdb_votes'], dtype='object')

# %%
df.columns[df.isnull().any()] # ustunlar bo'yicha NON qiymat lar mavjud ustunlar nomi
df.columns[df.isnull().any()]
df.columns[df.isnull().any()]
df.columns[df.isnull().any()]
df.columns[df.isnull().any()]
df.columns[df.isnull().any()]
df.columns[df.isnull().any()]
df[df.isnull().any(axis=1)] # qatorlar bo'yicha NON qiymatlar avjud qiymatlarni ko'rsatish
df[df.isnull().any(axis=1)]
df[df.isnull().any(axis=1)]
df[df.isnull().any(axis=1)]
df[df.isnull().any(axis=1)]
df[df.isnull().any(axis=1)]
# Out:
# Index(['id', 'type', 'description', 'age_certification', 'imdb_votes'], dtype='object')

# %%
a=3
b=4
print('ikki sonning yigindisi:',a+b,'ga teng')
# Out:
# ikki sonning yigindisi: 7 ga teng

# %%
a=4
b=3
print('a ning b chi darajasi',a**b,'gateng')
# Out:
# a ning b chi darajasi 64 gateng

# %%
a=3
b=4
pow(a,b)
# Out:
# 81

# %%
a=3
b=5
pow('a ning b inchi darajasi', a,b) # pow()codi  faqat float,int ni qabul qiladi sit ni qabul qilmaydi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 a=3
#       2 b=5
# ----> 3 pow('a ning b inchi darajasi', a,b) #
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str', 'int', 'int'
